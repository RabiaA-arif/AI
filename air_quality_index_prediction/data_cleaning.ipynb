# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("output.csv")

# %%
df
# Out:
#                                              City/Town  \
# 0    Abidjan (former capital; still hosts some gove...
# 1                               Yamoussoukro (de jure)
# 2                                            Abu Dhabi
# 3                                                Abuja
# 4                                                Accra
# ..                                                 ...
# 260                                           Windhoek
# 261                                            Yaoundé
# 262                                   Yaren (de facto)
# 263                                            Yerevan
# 264                                             Zagreb
#
#                Country/Territory    Continent  \
# 0    Ivory Coast (Côte d'Ivoire)       Africa
# 1                            NaN          NaN
# 2           United Arab Emirates         Asia
# 3                        Nigeria       Africa
# 4                          Ghana          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City/Town          265 non-null    object
#  1   Country/Territory  246 non-null    object
#  2   Continent          210 non-null    object
#  3   Notes              88 non-null     object
# dtypes: object(4)
# memory usage: 8.4+ KB

# %%
df.describe()
# Out:
#          City/Town            Country/Territory Continent  \
# count          265                          246       210
# unique         263                          246        19
# top     Georgetown  Ivory Coast (Côte d'Ivoire)    Africa
# freq             2                            1        44
#
#                               Notes
# count                            88
# unique                           68
# top     British Overseas Territory.
# freq                              8

# %%
df["Notes"].isnull().sum()
# Out:
# np.int64(177)

# %%
df["City/Town"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Country/Territory"].isnull().sum()
# Out:
# np.int64(19)

# %%
df["Continent"].isnull().sum()
# Out:
# np.int64(55)

# %%
df["Country/Territory"].unique
# Out:
# <bound method Series.unique of 0      Ivory Coast (Côte d'Ivoire)
# 1                              NaN
# 2             United Arab Emirates
# 3                          Nigeria
# 4                            Ghana
#                   ...
# 260                        Namibia
# 261                       Cameroon
# 262                          Nauru
# 263                        Armenia
# 264                        Croatia
# Name: Country/Territory, Length: 265, dtype: object>
