# %%
from bs4 import  BeautifulSoup  
import requests

# %%
url="https://en.wikipedia.org/wiki/List_of_national_capitals#List"

# %%
headers={'User-Agent': 'Mymlproject/0.0 (https://en.wikipedia.org/wiki/List_of_national_capitals#List; rabiaarifai55@gmail.com)'}
responce=requests.get(url,headers=headers)

# %%
print(responce)
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(responce.text,'html')

# %%
soup.find('table')
# Out:
# <table class="sidebar nomobile nowraplinks"><tbody><tr><th class="sidebar-title"><a href="/wiki/Lists_of_capitals" title="Lists of capitals">Lists of capitals</a></th></tr><tr><th class="sidebar-heading">
# Of countries</th></tr><tr><td class="sidebar-content" style="text-align: left">
# <ul><li><a class="mw-selflink selflink">In alphabetical order</a></li>
# <li><a href="/wiki/List_of_national_capitals_by_latitude" title="List of national capitals by latitude">By latitude</a></li>
# <li><a href="/wiki/List_of_national_capitals_by_population" title="List of national capitals by population">By population</a></li>
# <li><a href="/wiki/List_of_national_capitals_by_area" title="List of national capitals by area">By area</a></li>
# <li><a href="/wiki/List_of_capital_cities_by_elevation" title="List of capital cities by elevation">By elevation</a></li>
# <li><a href="/wiki/List_of_countries_whose_capital_is_not_their_largest_city" title="List of countries whose capital is not their largest city">Capital is not their largest city</a></li>
# <li><a href="/wiki/List_of_former_national_capitals" title="List of former national capitals">Former</a></li>
# <li><a href="/wiki/List_of_countries_with_multiple_capitals" title="List of countries with multiple capitals">Multiple capitals</a></li>
# <li><a href="/wiki/List_of_purpose-built_national_capitals" title="List of purpose-built national capitals">Purpose-built</a></li>
# <li><a href="/wiki/List_of_national_capitals_situated_on_an_international_border" title="List of national capitals situated on an international border">Situated on an international border</a></li>
# <li><a href="/wiki/Timeline_of_geopolitical_changes_(before_1500)" title="Timeline of geopolitical changes (before 1500)">Timeline of geopolitical changes (before 1500)</a></li>
# <li><a href="/wiki/Timeline_of_geopolitical_changes_(1500%E2%80%931899)" title="Timeline of geopolitical changes (1500–1899)">Timeline of geopolitical changes (1500–1899)</a></li>
# <li><a class="mw-redirect" href="/wiki/Timeline_of_geopolitical_changes_(1900%E2%88%921999)" title="Timeline of geopolitical changes (1900−1999)">Timeline of geopolitical changes (1900−1999)</a></li>
# <li><a class="mw-redirect" href="/wiki/Timeline_of_geopolitical_changes_(2000%E2%88%92present)" title="Timeline of geopolitical changes (2000−present)">Timeline of geopolitical changes (2000−present)</a></li></ul></td>
# </tr><tr><th class="sidebar-heading">
# Of country subdivisions</th></tr><tr><td class="sidebar-content" style="text-align: left">
# <ul><li><a href="/wiki/List_of_capitals_outside_the_territories_they_serve" title="List of capitals outside the territories they serve">Capitals outside the territories they serve</a></li>
# <li><a href="/wiki/List_of_purpose-built_capitals_of_country_subdivisions" title="List of purpose-built capitals of country subdivisions">Purpose-built</a></li></ul></td>
# </tr><tr><td class="sidebar-below">
# <i><b><span class="nowrap"><span class="noviewer" typeof="mw:File"><a class="mw-file-description" href="/wiki/File:COL-city_icon.png"><img alt="icon" class="mw-file-element" data-file-height="500" data-file-width="500" decoding="async" height="28" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b5/COL-city_icon.png/40px-COL-city_icon.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b5/COL-city_icon.png/60px-COL-city_icon.png 1.5x" width="28"/></a></span> </span><a href="/wiki/Portal:Cities" title="Portal:Cities">Cities portal</a></b></i></td></tr><tr><td class="sidebar-navbar"><link href="mw-data:TemplateStyles:r1129693374" rel="mw-deduplicated-inline-style"/><style data-mw-deduplicate="TemplateStyles:r1239400231">.mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}html.skin-theme-clientpref-night .mw-parser-output .navbar li a abbr{color:var(--color-base)!important}@media(prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .navbar li a abbr{color:var(--color-base)!important}}@media print{.mw-parser-output .navbar{display:none!important}}</style><div class="navbar plainlinks hlist navbar-mini"><ul><li class="nv-view"><a href="/wiki/Template:Lists_of_capitals" title="Template:Lists of capitals"><abbr title="View this template">v</abbr></a></li><li class="nv-talk"><a href="/wiki/Template_talk:Lists_of_capitals" title="Template talk:Lists of capitals"><abbr title="Discuss this template">t</abbr></a></li><li class="nv-edit"><a href="/wiki/Special:EditPage/Template:Lists_of_capitals" title="Special:EditPage/Template:Lists of capitals"><abbr title="Edit this template">e</abbr></a></li></ul></div></td></tr></tbody></table>

# %%
# table=soup.find('table',class_="wikitable sortable sticky-header jquery-tablesorter")

# %%
table=soup.find('table',class_="wikitable sortable sticky-header jquery-tablesorter")

# %%
table

# %%
world_titles=soup.find_all('th')

# %%
world_titles
# Out:
# [<th class="sidebar-title"><a href="/wiki/Lists_of_capitals" title="Lists of capitals">Lists of capitals</a></th>,
#  <th class="sidebar-heading">
#  Of countries</th>,
#  <th class="sidebar-heading">
#  Of country subdivisions</th>,
#  <th scope="col" style="width:130px;">City/Town
#  </th>,
#  <th scope="col" style="width:200px;">Country/Territory
#  </th>,
#  <th>Continent
#  </th>,
#  <th class="sortable">Notes
#  </th>]

# %%
# soup.find('table',class_="sidebar-heading")

# %%
world_titles_table=[title.text.strip() for title in world_titles]
print(world_titles_table)
# Out:
# ['Lists of capitals', 'Of countries', 'In alphabetical order\nBy latitude\nBy population\nBy area\nBy elevation\nCapital is not their largest city\nFormer\nMultiple capitals\nPurpose-built\nSituated on an international border\nTimeline of geopolitical changes (before 1500)\nTimeline of geopolitical changes (1500–1899)\nTimeline of geopolitical changes (1900−1999)\nTimeline of geopolitical changes (2000−present)', 'Of country subdivisions', 'Capitals outside the territories they serve\nPurpose-built', 'Cities portal', 'vte', 'City/Town\n\nCountry/Territory\n\nContinent\n\nNotes', "Abidjan (former capital; still hosts some government offices)\n\xa0Ivory Coast (Côte d'Ivoire)\n\nAfrica\nAbidjan is the largest city in Ivory Coast and is officially designated as the economic capital.", 'Yamoussoukro (de jure)', 'Abu Dhabi\n\xa0United Arab Emirates\n\nAsia', 'Abuja\n\xa0Nigeria\n\nAfrica\nLagos was the capital from 1914 to 1991.', 'Accra\n\xa0Ghana', 'Adamstown\n\xa0Pitcairn Islands\n\nOceania\nBritish Overseas Territory.', 'Addis Ababa\n\xa0Ethiopia\n\nAfrica', "Aden (de facto, temporary)\n\xa0Yemen\n\nAsia\nYemen is in a state of civil war, and Sanaa has been occupied by Houthi rebels since September 2014. Aden, the former capital of South Yemen, is Yemen's acting capital.", 'Sanaa (de jure)', 'Episkopi Cantonment\n\xa0Akrotiri and Dhekelia\nBritish Overseas Territory.', 'Algiers\n\xa0Algeria\n\nAfrica', 'Alofi\n\xa0Niue\n\nOceania\nSelf-governing in free association with New Zealand. Government offices are spread across both Alofi North and Alofi South.', 'Amman\n\xa0Jordan\n\nAsia', 'Amsterdam (official)\n\xa0Netherlands\n\nEurope\nThe Hague hosts the monarch, government ministries, judiciary and diplomatic missions. See also Capital of the Netherlands.', 'The Hague (de facto)', 'Andorra la Vella\n\xa0Andorra', "Ankara\n\xa0Turkey\n\nAsia\nAnkara became capital of the newly-formed Republic of Turkey in 1923, after the Turkish War of Independence. The capital of Turkey's predecessor, the Ottoman Empire, was Constantinople (now Istanbul).", 'Antananarivo\n\xa0Madagascar\n\nAfrica', 'Apia\n\xa0Samoa\n\nOceania', 'Ashgabat\n\xa0Turkmenistan\n\nAsia', 'Asmara\n\xa0Eritrea\n\nAfrica', 'Astana\n\xa0Kazakhstan\n\nAsia\nAstana was named Nur-Sultan from 2019 to 2022. Almaty was the capital of Kazakhstan from 1991 to 1997 and its predecessor the Kazakh SSR from 1929 to 1991.', 'Asunción\n\xa0Paraguay\n\nSouth America', 'Atafu (atoll administration)\n\xa0Tokelau\n\nOceania\nMost populous city and smallest atoll. New Zealand owns Tokelau.', 'Nukunonu (atoll administration)\nLargest atoll. the population of people living there is 531.', 'Fakaofo (atoll administration)\nMost populous city in this atoll is Fale, Tokelau', 'Athens\n\xa0Greece\n\nEurope', 'Avarua\n\xa0Cook Islands\n\nOceania\nSelf-governing in free association with New Zealand. The capital is sometimes incorrectly stated as Rarotonga, the island on which Avarua is located.', 'Baghdad\n\xa0Iraq\n\nAsia', 'Baku\n\xa0Azerbaijan\n\nAsia/Europe', 'Bamako\n\xa0Mali\n\nAfrica', 'Bandar Seri Begawan\n\xa0Brunei\n\nAsia', 'Bangkok\n\xa0Thailand', 'Bangui\n\xa0Central African Republic\n\nAfrica', 'Banjul\n\xa0Gambia', 'Basseterre\n\xa0Saint Kitts and Nevis\n\nNorth America', 'Beijing\n\xa0China\n\nAsia\nSee also: Historical capitals of China.', 'Beirut\n\xa0Lebanon', 'Belgrade\n\xa0Serbia\n\nEurope', "Belmopan\n\xa0Belize\n\nNorth America\nBelize City was the capital of Belize's predecessor, British Honduras.", 'Berlin\n\xa0Germany\n\nEurope\nBonn was the capital of West Germany and remained the seat of government for reunified Germany until 1999, and is still the primary seat of six ministries. See also Capital of Germany.', 'Bern (de facto)\n\xa0Switzerland', 'Bishkek\n\xa0Kyrgyzstan\n\nAsia', 'Bissau\n\xa0Guinea-Bissau\n\nAfrica', 'Bloemfontein (judicial)\n\xa0South Africa', 'Cape Town (legislative)', 'Pretoria (executive)', 'Bogotá\n\xa0Colombia\n\nSouth America', 'Brades (de facto)\n\ ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(columns=world_titles_table)
df
# Out:
# Empty DataFrame
# Columns: [Lists of capitals, Of countries, Of country subdivisions, City/Town, Country/Territory, Continent, Notes]
# Index: []

# %%
column_data=table.find_all('tr')

# %%
for row in column_data[1:]:
   row_data= row.find_all('td')
   individual_row_data=[data.text.strip() for data in row_data]
print(individual_row_data)
   # length=len(df)
   # df.loc[length]=individual_row_data
# Out:
# ['Zagreb', 'Croatia', 'Europe', '']

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\LENOVO\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\pandas\\__init__.py'>
